# %% [markdown]
# .env → load API key → create Gemini client →
# send question → receive AI response →
# extract text → print → display formatted

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os
from IPython.display import Markdown, display

# Load environment variables
load_dotenv(override=True)

# Gemini API configuration
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
google_api_key = os.getenv("GOOGLE_API_KEY")

# Create Gemini client
gemini = OpenAI(
    api_key=google_api_key,
    base_url=GEMINI_BASE_URL
)

# Messages (your question)
messages = [
    {"role": "user", "content": "Explain what is 2+2 in simple terms."}
]

# Send request to Gemini
response = gemini.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages
)

# Extract answer
answer = response.choices[0].message.content

# Print normal output
print(answer)

# Display nicely formatted Markdown (for Jupyter/Colab)
display(Markdown(answer))
# Out:
# 2 + 2 equals **4**.
#
# Here's how to think about it in simple terms:
#
# 1.  **Start with two things.** (Imagine you have two apples, or two cookies.)
# 2.  The **'+' sign** means you're adding more to what you already have.
# 3.  **Add another two things.** (So, you take your first two apples, and you add *another* two apples to them.)
# 4.  If you put them all together and **count them**, you would count: one, two, three, four.
#
# That's why 2 + 2 = 4.
#
# Think of it like holding up two fingers on one hand, and two fingers on the other hand. How many fingers are up in total? Four!
# 2 + 2 equals **4**.
#
# Here's how to think about it in simple terms:
#
# 1.  **Start with two things.** (Imagine you have two apples, or two cookies.)
# 2.  The **'+' sign** means you're adding more to what you already have.
# 3.  **Add another two things.** (So, you take your first two apples, and you add *another* two apples to them.)
# 4.  If you put them all together and **count them**, you would count: one, two, three, four.
#
# That's why 2 + 2 = 4.
#
# Think of it like holding up two fingers on one hand, and two fingers on the other hand. How many fingers are up in total? Four!
