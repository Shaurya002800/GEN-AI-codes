# %% [markdown]
# .env → load API key → create Gemini client →
# send question → receive AI response →
# extract text → print → display formatted

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os
from IPython.display import Markdown, display

# Load environment variables
load_dotenv(override=True)

# Gemini API configuration
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
google_api_key = os.getenv("GOOGLE_API_KEY")

# Create Gemini client
gemini = OpenAI(
    api_key=google_api_key,
    base_url=GEMINI_BASE_URL
)

# Messages (your question)
messages = [
    {"role": "user", "content": "Explain what is 2+2 in simple terms."}
]

# Send request to Gemini
response = gemini.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages
)

# Extract answer
answer = response.choices[0].message.content

# Print normal output
print(answer)

# Display nicely formatted Markdown (for Jupyter/Colab)
display(Markdown(answer))
# Out:
# 2 + 2 means you have **two of something**, and then you **add two more** of those things.
#
# Imagine you have:
#
# *   **Two apples** (🍎🍎)
# *   And then someone gives you **two more apples** (🍎🍎)
#
# If you count all the apples you have now, you'll have:
#
# 🍎 🍎 🍎 🍎
#
# That's **four apples** in total.
#
# So, 2 + 2 = 4.
# 2 + 2 means you have **two of something**, and then you **add two more** of those things.
#
# Imagine you have:
#
# *   **Two apples** (🍎🍎)
# *   And then someone gives you **two more apples** (🍎🍎)
#
# If you count all the apples you have now, you'll have:
#
# 🍎 🍎 🍎 🍎
#
# That's **four apples** in total.
#
# So, 2 + 2 = 4.
